# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhishrahul/GenAI/blob/main/GenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
key = userdata.get('GEMINI_API_KEY')

# %%
from google import genai

client = genai.Client(api_key = key)

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="Hello, I'm Nidhish"
)

# %%
interaction
# Out:
# Interaction(status='completed', model='gemini-3.5-flash', agent=None, id='v1_ChdQSGxZYXFhbkh1T3pqTWNQdGRhM2lBMBIXUEhsWWFxYW5IdU96ak1jUHRkYTNpQTA', created='2026-07-16T06:25:00Z', updated='2026-07-16T06:25:00Z', system_instruction=None, tools=None, usage=Usage(total_input_tokens=9, input_tokens_by_modality=[ModalityTokens(modality='text', tokens=9)], total_cached_tokens=0, cached_tokens_by_modality=None, total_output_tokens=20, output_tokens_by_modality=None, total_tool_use_tokens=0, tool_use_tokens_by_modality=None, total_thought_tokens=252, total_tokens=281, grounding_tool_count=None), response_modalities=None, response_mime_type=None, previous_interaction_id=None, environment_id=None, service_tier='standard', webhook_config=None, steps=[ThoughtStep(type='thought', signature='...', summary=None), ModelOutputStep(type='model_output', content=[TextContent(text="Hello Nidhish! It's great to meet you. How can I help you today?", type='text', annotations=None)], error=None)], response_format=None, environment=None, generation_config=None, cached_content=None, agent_config=None, input=None, output_text="Hello Nidhish! It's great to meet you. How can I help you today?", output_image=None, output_audio=None, output_video=None, object='interaction')

# %%
interaction2 = client.interactions.create(
    model="gemini-3.5-flash",
    input="SAY MY NAME !",
    previous_interaction_id = interaction.id
)

# %%
interaction2
# Out:
# Interaction(status='completed', model='gemini-3.5-flash', agent=None, id='v1_ChdQSGxZYXFhbkh1T3pqTWNQdGRhM2lBMBIXaUhsWWFxZThGLWlJLXNBUHJmYTE4QW8', created='2026-07-16T06:26:16Z', updated='2026-07-16T06:26:16Z', system_instruction=None, tools=None, usage=Usage(total_input_tokens=288, input_tokens_by_modality=[ModalityTokens(modality='text', tokens=288)], total_cached_tokens=0, cached_tokens_by_modality=None, total_output_tokens=10, output_tokens_by_modality=None, total_tool_use_tokens=0, tool_use_tokens_by_modality=None, total_thought_tokens=299, total_tokens=597, grounding_tool_count=None), response_modalities=None, response_mime_type=None, previous_interaction_id=None, environment_id=None, service_tier='standard', webhook_config=None, steps=[ThoughtStep(type='thought', signature='...', summary=None), ModelOutputStep(type='model_output', content=[TextContent(text='Your name is **Nidhish**! 🙌', type='text', annotations=None)], error=None)], response_format=None, environment=None, generation_config=None, cached_content=None, agent_config=None, input=None, output_text='Your name is **Nidhish**! 🙌', output_image=None, output_audio=None, output_video=None, object='interaction')
